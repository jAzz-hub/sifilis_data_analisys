# %% [markdown]
# ### Importando bibliotecas

# %%
from pandas import read_csv, read_excel, isna

from math import isnan

from myFunctions import *

import pickleshare

#from numpy import

#from matplotlib import

#from scipy import

#from sklearn import

# %% [markdown]
# ### Consumindo dados em CSV:

# %%
df = read_csv('../Data/CSV/RELATORIO-DE-SIFILIS-EM-GESTANTE2019-A-2023MOC.csv', sep=",", encoding='latin1', engine='python', thousands='.', decimal=',')
df.drop('DSMOTIVO', axis=1, inplace=True)
df.drop('ID_AGRAVO', axis=1, inplace=True)
df.drop('ID_MN_RESI', axis=1, inplace=True)
df.drop('MN_RESIDENCIS', axis=1, inplace=True)
tratando_Nan(df)

print(df)

df.head(10)
# Out:
#     DT_NOTIFIC  NU_ANO  ID_MUNICIP  ID_UNIDADE     DT_DIAG  NU_IDADE_N  \
# 0    1/28/2021    2021      314330     5998220   10/2/2020        4020
# 1     1/8/2021    2021      314330     2219654  12/23/2020        4022
# 2     2/6/2021    2021      314330     2219654    2/6/2021        4017
# 3     2/9/2021    2021      314330     2219654   12/7/2020        4032
# 4    2/11/2021    2021      314330     2149990    2/1/2021        4026
# ..         ...     ...         ...         ...         ...         ...
# 747  9/19/2022    2022      314330     2219077   9/19/2022        4020
# 748  10/5/2020    2020      314330     2219654   10/5/2020        4026
# 749  6/30/2021    2021      314330     2149990   6/29/2021        4017
# 750   9/6/2022    2022      314330     2219654    9/6/2022        4021
# 751  6/24/2022    2022      314330     2219654   6/24/2022        4019
#
#      CS_GESTANT  CS_RACA  CS_ESCOL_N  CS_ZONA  TPCONFIRMA  TPESQUEMA  \
# 0             3      1.0         NaN      1.0         3.0        3.0
# 1             3      4.0         9.0      1.0         1.0        5.0
# 2             3      4.0         9.0      1.0         3.0        3.0
# 3             3      4.0         NaN      1.0         9.0        5.0
# 4             3      1.0         9.0      1.0         1.0        3.0
# ..          ...      ...         ...      ...         ...        ...
# 747           3      4.0         9.0      1.0         1.0        3.0
# 748           4      2.0         9.0      1.0         3.0        1.0
# 749           3      4.0         9.0      1.0         1.0        1.0
# 750           2      4.0         NaN      1.0         1.0        3.0
# 751           3      4.0         9.0      1.0         2.0        1.0
#
#          TPMOTPARC  TPESQPAR  TRATPARC  CLASSI_FIN
# 0              1.0       5.0       2.0         1.0
# 1    Não Informado       5.0       2.0         1.0
# 2              6.0       5.0       2.0         1.0
# 3              1.0       5.0       2.0         1.0
# 4    Não Informado       5.0       2.0         1.0
# ..             ...       ...       ...         ...
# 747  Não Informado       1.0       1.0         1.0
# 748            2.0       5.0       2.0         1.0
# 749  Não Informado       5.0       2.0         1.0
# 750  Não Informado       1.0       1.0         1.0
# 751  Não Informado       1.0       1.0         1.0
#
# [752 rows x 16 columns]
# c:\Users\joaog\OneDrive\Área de Trabalho\CEFET2\sifilis_data_analisys\Code\myFunctions.py:27: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['TPMOTPARC'].fillna('Não Informado', inplace=True)
# c:\Users\joaog\OneDrive\Área de Trabalho\CEFET2\sifilis_data_analisys\Code\myFunctions.py:27: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Não Informado' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df['TPMOTPARC'].fillna('Não Informado', inplace=True)
#   DT_NOTIFIC  NU_ANO  ID_MUNICIP  ID_UNIDADE     DT_DIAG  NU_IDADE_N  \
# 0  1/28/2021    2021      314330     5998220   10/2/2020        4020
# 1   1/8/2021    2021      314330     2219654  12/23/2020        4022
# 2   2/6/2021    2021      314330     2219654    2/6/2021        4017
# 3   2/9/2021    2021      314330     2219654   12/7/2020        4032
# 4  2/11/2021    2021      314330     2149990    2/1/2021        4026
# 5  2/16/2021    2021      314330     2219654   2/13/2021        4023
# 6  2/13/2021    2021      314330     2219654   2/12/2021        4028
# 7  9/10/2021    2021      314330     2219654   9/10/2021        4032
# 8  2/18/2021    2021      314330     2149990   2/16/2021        4019
# 9   3/1/2021    2021      314330     9854304    3/1/2021        4030
#
#    CS_GESTANT  CS_RACA  CS_ESCOL_N  CS_ZONA  TPCONFIRMA  TPESQUEMA  \
# 0           3      1.0         NaN      1.0         3.0        3.0
# 1           3      4.0         9.0      1.0         1.0        5.0
# 2           3      4.0         9.0      1.0         3.0        3.0
# 3           3      4.0         NaN      1.0         9.0        5.0
# 4           3      1.0         9.0      1.0         1.0        3.0
# 5           1      4.0         6.0      1.0         9.0        3.0
# 6           3      4.0         9.0      9.0         1.0        3.0
# 7           3      4.0         9.0      1.0         1.0        3.0
# 8           3      2.0         9.0      1.0         1.0        3.0
# 9           2      4.0         9.0      1.0         3.0        3.0
#
#        TPMOTPARC  TPESQPAR  TRATPARC  CLASSI_FIN
# 0            1.0       5.0       2.0         1.0
# 1  Não Informado       5.0       2.0         1.0
# 2            6.0       5.0       2.0         1.0
# 3            1.0       5.0       2.0         1.0
# 4  Não Informado       5.0       2.0         1.0
# 5            2.0       5.0       2.0         1.0
# 6  Não Informado       5.0       2.0         1.0
# 7  Não Informado       5.0       2.0         1.0
# 8  Não Informado       5.0       2.0         1.0
# 9  Não Informado       3.0       1.0         1.0

# %% [markdown]
# ### Modificando o nome das colunas

# %%
rename_df_columns(df)
df.rename(columns={
    'NU_IDADE_N' : 'Idade'
    }, inplace=True)
print(df)
# Out:
#     Data_Notificacao   Ano  ID_MUNICIP  Unidade     DT_DIAG  Idade  \
# 0          1/28/2021  2021      314330  5998220   10/2/2020   4020
# 1           1/8/2021  2021      314330  2219654  12/23/2020   4022
# 2           2/6/2021  2021      314330  2219654    2/6/2021   4017
# 3           2/9/2021  2021      314330  2219654   12/7/2020   4032
# 4          2/11/2021  2021      314330  2149990    2/1/2021   4026
# ..               ...   ...         ...      ...         ...    ...
# 747        9/19/2022  2022      314330  2219077   9/19/2022   4020
# 748        10/5/2020  2020      314330  2219654   10/5/2020   4026
# 749        6/30/2021  2021      314330  2149990   6/29/2021   4017
# 750         9/6/2022  2022      314330  2219654    9/6/2022   4021
# 751        6/24/2022  2022      314330  2219654   6/24/2022   4019
#
#      TriGestacional  Raca  Escolaridade  Residencia  TPCONFIRMA  Tratamento  \
# 0                 3   1.0           NaN         1.0         3.0         3.0
# 1                 3   4.0           9.0         1.0         1.0         5.0
# 2                 3   4.0           9.0         1.0         3.0         3.0
# 3                 3   4.0           NaN         1.0         9.0         5.0
# 4                 3   1.0           9.0         1.0         1.0         3.0
# ..              ...   ...           ...         ...         ...         ...
# 747               3   4.0           9.0         1.0         1.0         3.0
# 748               4   2.0           9.0         1.0         3.0         1.0
# 749               3   4.0           9.0         1.0         1.0         1.0
# 750               2   4.0           NaN         1.0         1.0         3.0
# 751               3   4.0           9.0         1.0         2.0         1.0
#
#          TPMOTPARC  TPESQPAR  TratamentoParceiro  CLASSI_FIN
# 0              1.0       5.0                 2.0         1.0
# 1    Não Informado       5.0                 2.0         1.0
# 2              6.0       5.0                 2.0         1.0
# 3              1.0       5.0                 2.0         1.0
# 4    Não Informado       5.0                 2.0         1.0
# ..             ...       ...                 ...         ...
# 747  Não Informado       1.0                 1.0         1.0
# 748            2.0       5.0                 2.0         1.0
# 749  Não Informado       5.0                 2.0         1.0
# 750  Não Informado       1.0                 1.0         1.0
# 751  Não Informado       1.0                 1.0         1.0
#
# [752 rows x 16 columns]

# %%
df.head()
# Out:
#   Data_Notificacao   Ano  ID_MUNICIP  Unidade     DT_DIAG  Idade  \
# 0        1/28/2021  2021      314330  5998220   10/2/2020   4020
# 1         1/8/2021  2021      314330  2219654  12/23/2020   4022
# 2         2/6/2021  2021      314330  2219654    2/6/2021   4017
# 3         2/9/2021  2021      314330  2219654   12/7/2020   4032
# 4        2/11/2021  2021      314330  2149990    2/1/2021   4026
#
#    TriGestacional  Raca  Escolaridade  Residencia  TPCONFIRMA  Tratamento  \
# 0               3   1.0           NaN         1.0         3.0         3.0
# 1               3   4.0           9.0         1.0         1.0         5.0
# 2               3   4.0           9.0         1.0         3.0         3.0
# 3               3   4.0           NaN         1.0         9.0         5.0
# 4               3   1.0           9.0         1.0         1.0         3.0
#
#        TPMOTPARC  TPESQPAR  TratamentoParceiro  CLASSI_FIN
# 0            1.0       5.0                 2.0         1.0
# 1  Não Informado       5.0                 2.0         1.0
# 2            6.0       5.0                 2.0         1.0
# 3            1.0       5.0                 2.0         1.0
# 4  Não Informado       5.0                 2.0         1.0

# %% [markdown]
# ### Conferindo todas as variáveis possíveis de uma coluna

# %%
df['Residencia'].unique()
# Out:
# array([ 1.,  9., nan,  2.])

# %% [markdown]
# ### Observando quais colunas possuem linhas Nan e vazias

# %%
# print(df)
print(Count_null_values(df))
df.dropna(inplace=True)
print(df)
# Out:
# {'Data_Notificacao': 0, 'Ano': 0, 'ID_MUNICIP': 0, 'Unidade': 0, 'DT_DIAG': 0, 'Idade': 0, 'TriGestacional': 0, 'Raca': 13, 'Escolaridade': 71, 'Residencia': 16, 'TPCONFIRMA': 1, 'Tratamento': 1, 'TPMOTPARC': 0, 'TPESQPAR': 17, 'TratamentoParceiro': 7, 'CLASSI_FIN': 25}
#     Data_Notificacao   Ano  ID_MUNICIP  Unidade     DT_DIAG  Idade  \
# 1           1/8/2021  2021      314330  2219654  12/23/2020   4022
# 2           2/6/2021  2021      314330  2219654    2/6/2021   4017
# 4          2/11/2021  2021      314330  2149990    2/1/2021   4026
# 5          2/16/2021  2021      314330  2219654   2/13/2021   4023
# 6          2/13/2021  2021      314330  2219654   2/12/2021   4028
# ..               ...   ...         ...      ...         ...    ...
# 746         5/4/2021  2021      314330  2149990    5/4/2021   4019
# 747        9/19/2022  2022      314330  2219077   9/19/2022   4020
# 748        10/5/2020  2020      314330  2219654   10/5/2020   4026
# 749        6/30/2021  2021      314330  2149990   6/29/2021   4017
# 751        6/24/2022  2022      314330  2219654   6/24/2022   4019
#
#      TriGestacional  Raca  Escolaridade  Residencia  TPCONFIRMA  Tratamento  \
# 1                 3   4.0           9.0         1.0         1.0         5.0
# 2                 3   4.0           9.0         1.0         3.0         3.0
# 4                 3   1.0           9.0         1.0         1.0         3.0
# 5                 1   4.0           6.0         1.0         9.0         3.0
# 6                 3   4.0           9.0         9.0         1.0         3.0
# ..              ...   ...           ...         ...         ...         ...
# 746               3   9.0           9.0         1.0         1.0         4.0
# 747               3   4.0           9.0         1.0         1.0         3.0
# 748               4   2.0           9.0         1.0         3.0         1.0
# 749               3   4.0           9.0         1.0         1.0         1.0
# 751               3   4.0           9.0         1.0         2.0         1.0
#
#          TPMOTPARC  TPESQPAR  TratamentoParceiro  CLASSI_FIN
# 1    Não Informado       5.0                 2.0         1.0
# 2              6.0       5.0                 2.0         1.0
# 4    Não Informado       5.0                 2.0         1.0
# 5              2.0       5.0                 2.0         1.0
# 6    Não Informado       5.0                 2.0         1.0
# ..             ...       ...                 ...         ...
# 746  Não Informado       5.0                 2.0         1.0
# 747  Não Informado       1.0                 1.0         1.0
# 748            2.0       5.0                 2.0         1.0
# 749  Não Informado       5.0                 2.0         1.0
# 751  Não Informado       1.0                 1.0         1.0
#
# [625 rows x 16 columns]

# %% [markdown]
# ### Extraindo as idades da coluna NU_IDADE_N

# %%
# df = df[df['Escolaridade'] != 9]

df['Idade'] = df['Idade'].apply(lambda x: x % 100)

# %% [markdown]
# #### Substituindo dados sobre raças e Zona de Residência

# %%
# Mapeamento de valores para as etnias
mapeamento_raca = {
    1: 'Branca',
    2: 'Preta',
    3: 'Amarela',
    4: 'Parda',
    5: 'Indígena',
    9: 'Não Assinalado na Ficha'
}

mapeamento_resid = {
    1 :'Urbana',
    2 :'Rural',
    3 :'Periurbana',
    9 :'Ignorado'
}

mapeamento_escolaridade = {
    1:'1ª a 4ª série incompleta do EF',
    2:'4ª série completa do EF',
    3:'5ª à 8ª série incompleta do EF',
    4:'Fundamental completo',
    5:'Médio incompleto ',
    6:'Médio completo ',
    7:'Superior incompleta',
    8:'Educação superior completa',
    9:'Ignorado',
    10: 'Não se aplica'
}

mapeamento_trat = {
1 :"Penicilina G benzantina 2.400.000 UI ",
2 :"Penicilina G benzantina 4.800.000 UI ",
3 :"Penicilina G benzantina 7.200.000 UI",
4 :"Outro esquema ",
5 :"Não realizado ",
9 :"Ignorado"
}

mapeamento_trigest = {
1 :"1º",
2 :"2º",
3 :"3º",
4 :"Idade Gestacional Ignorada",
9 :"Ignorado",
}

# Substituir os valores na coluna 'etnia'
df['Raca'] = df['Raca'].map(mapeamento_raca)
df['Residencia'] = df['Residencia'].map(mapeamento_resid)
df['Escolaridade'] = df['Escolaridade'].map(mapeamento_escolaridade)
df['Tratamento'] = df['Tratamento'].map(mapeamento_trat)
df['TriGestacional'] = df['TriGestacional'].map(mapeamento_trigest)

# %%
# Função para converter a formatação
def formatar_penicilina(valor):
    if isna(valor):  # Se for NaN, mantém como está
        return valor
    elif "4.800.000" in valor:
        return "PGB 4.800.000 UI"
        print("AQUI")
    elif "2.400.000" in valor:
        return "PGB 2.400.000 UI"
        print("AQUI")
    elif "7.200.000" in valor:
        return "PGB 7.200.000 UI"
        print("AQUI")
    else:
        return valor  # Retorna o valor original caso não se encaixe nos padrões
        print("AQUI")

# Aplicando a conversão na coluna de tratamento
df['Tratamento'] = df['Tratamento'].apply(formatar_penicilina)

# Exibindo alguns valores para conferir
print(df['Tratamento'].unique())
# Out:
# ['Não realizado ' 'Penicilina G benzantina 7,2×10⁵ UI'
#  'Penicilina G benzantina 2,4×10⁵ UI' 'Outro esquema '
#  'PGB Penicilina G benzantina 4,8×10⁵ UI' 'Ignorado']

# %% [markdown]
# ### Uma breve análise dos dados

# %%
print(df['Ano'].value_counts())
print(df['Unidade'].value_counts())
print(df['TriGestacional'].value_counts())
print(df['Raca'].value_counts())
print(df['Escolaridade'].value_counts())
print(df['Residencia'].value_counts())
print(df['Tratamento'].value_counts())
print(df['TratamentoParceiro'].value_counts())

print(df['TPCONFIRMA'].value_counts())
# Out:
# Ano
# 2021    154
# 2019    127
# 2020    122
# 2022    119
# 2023    103
# Name: count, dtype: int64
# Unidade
# 2219654    207
# 2149990    152
# 7366108     29
# 5492300     10
# 2219069      9
#           ...
# 2150093      1
# 6329632      1
# 2219085      1
# 9344381      1
# 5302897      1
# Name: count, Length: 84, dtype: int64
# TriGestacional
# 3º                            267
# 1º                            143
# Idade Gestacional Ignorada    116
# 2º                             99
# Name: count, dtype: int64
# Raca
# Parda                      402
# Não Assinalado na Ficha    134
# Branca                      46
# Preta                       40
# Amarela                      2
# Indígena                     1
# Name: count, dtype: int64
# Escolaridade
# Ignorado                          395
# Médio completo                    110
# Médio incompleto                   50
# 5ª à 8ª série incompleta do EF     26
# Fundamental completo               17
# Superior incompleta                 9
# 4ª série completa do EF             7
# Educação superior completa          6
# 1ª a 4ª série incompleta do EF      5
# Name: count, dtype: int64
# Residencia
# Urbana      614
# Rural         9
# Ignorado      2
# Name: count, dtype: int64
# Tratamento
# Penicilina G benzantina 7,2×10⁵ UI        336
# Penicilina G benzantina 2,4×10⁵ UI        128
# Outro esquema                              69
# Não realizado                              35
# PGB Penicilina G benzantina 4,8×10⁵ UI     33
# Ignorado                                   24
# Name: count, dtype: int64
# TratamentoParceiro
# 2.0    385
# 1.0    189
# 9.0     51
# Name: count, dtype: int64
# TPCONFIRMA
# 1.0    424
# 3.0    149
# 9.0     39
# 2.0     13
# Name: count, dtype: int64

# %% [markdown]
# ### Análise Descritiva Inicial

# %%
#Raça da gestante: Proporção por categorias.
print("\nRaça por gestante:")
print(df['Raca'].value_counts(normalize=True) * 100)

#Zona de residência: Frequência por zona (rural, urbana, etc.).
print("\nResidência por gestante:")
print(df['Residencia'].value_counts(normalize=True) * 100)

#Grau de escolaridade: Percentuais por níveis de escolaridade.
print("\nEscolaridade por gestante:")
print(df['Escolaridade'].value_counts(normalize=True) * 100)

#Trimestre gestacional do diagnóstico: Identificar em que trimestre a maioria dos casos foram diagnosticados#.
print("\nTrimestre gestacional por gestante:")
print(df['TriGestacional'].value_counts(normalize=True) * 100)
# Out:
# Raça por gestante:
# Raca
# Parda                      64.32
# Não Assinalado na Ficha    21.44
# Branca                      7.36
# Preta                       6.40
# Amarela                     0.32
# Indígena                    0.16
# Name: proportion, dtype: float64
#
# Residência por gestante:
# Residencia
# Urbana      98.24
# Rural        1.44
# Ignorado     0.32
# Name: proportion, dtype: float64
#
# Escolaridade por gestante:
# Escolaridade
# Ignorado                          63.20
# Médio completo                    17.60
# Médio incompleto                   8.00
# 5ª à 8ª série incompleta do EF     4.16
# Fundamental completo               2.72
# Superior incompleta                1.44
# 4ª série completa do EF            1.12
# Educação superior completa         0.96
# 1ª a 4ª série incompleta do EF     0.80
# Name: proportion, dtype: float64
#
# Trimestre gestacional por gestante:
# TriGestacional
# 3º                            42.72
# 1º                            22.88
# Idade Gestacional Ignorada    18.56
# 2º                            15.84
# Name: proportion, dtype: float64

# %%
df.to_csv('../Data/CSV/csv_sifilis_moc_2019_2023.csv', sep=",", encoding='latin1', decimal=',', index=False)
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 df.to_csv('../Data/CSV/csv_sifilis_moc_2019_2023.csv', sep=",", encoding='latin1', decimal=',', index=False)
#
# File c:\Users\joaog\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File c:\Users\joaog\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:3967, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3956 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3958 formatter = DataFrameFormatter(
#    3959     frame=df,
#    3960     header=header,
#    (...)
#    3964     decimal=decimal,
#    3965 )
# -> 3967 return DataFrameRenderer(formatter).to_csv(
#    3968     path_or_buf,
#    3969     lineterminator=lineterminator,
#    3970     sep=sep,
#    3971     encoding=encoding,
#    3972     errors=errors,
#    3973     compression=compression,
#    3974     quoting=quoting,
#    3975     columns=columns,
#    3976     index_label=index_label,
#    3977     mode=mode,
#    3978     chunksize=chunksize,
#    3979     quotechar=quotechar,
#    3980     date_format=date_format,
#    3981     doublequote=doublequote,
#    3982     escapechar=escapechar,
#    3983     storage_options=storage_options,
#    3984 )
#
# File c:\Users\joaog\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\formats\format.py:1014, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#     993     created_buffer = False
#     995 csv_formatter = CSVFormatter(
#     996     path_or_buf=path_or_buf,
#     997     lineterminator=lineterminator,
#    (...)
#    1012     formatter=self.fmt,
#    1013 )
# -> 1014 csv_formatter.save()
#    1016 if created_buffer:
#    1017     assert isinstance(path_or_buf, StringIO)
#
# File c:\Users\joaog\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\formats\csvs.py:270, in CSVFormatter.save(self)
#     251 with get_handle(
#     252     self.filepath_or_buffer,
#     253     self.mode,
#    (...)
#     258 ) as handles:
#     259     # Note: self.encoding is irrelevant here
#     260     self.writer = csvlib.writer(
#     261         handles.handle,
#     262         lineterminator=self.lineterminator,
#    (...)
#     267         quotechar=self.quotechar,
#     268     )
# --> 270     self._save()
#
# File c:\Users\joaog\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\formats\csvs.py:275, in CSVFormatter._save(self)
#     273 if self._need_to_save_header:
#     274     self._save_header()
# --> 275 self._save_body()
#
# File c:\Users\joaog\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\formats\csvs.py:313, in CSVFormatter._save_body(self)
#     311 if start_i >= end_i:
#     312     break
# --> 313 self._save_chunk(start_i, end_i)
#
# File c:\Users\joaog\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\formats\csvs.py:324, in CSVFormatter._save_chunk(self, start_i, end_i)
#     321 data = list(res._iter_column_arrays())
#     323 ix = self.data_index[slicer]._get_values_for_csv(**self._number_format)
# --> 324 libwriters.write_csv_rows(
#     325     data,
#     326     ix,
#     327     self.nlevels,
#     328     self.cols,
#     329     self.writer,
#     330 )
#
# File writers.pyx:73, in pandas._libs.writers.write_csv_rows()
#
# UnicodeEncodeError: 'latin-1' codec can't encode character '\u2075' in position 103: ordinal not in range(256)
